# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
train_dir = "Potato/Train/"
test_dir = "Potato/Test/"
valid_dir = "Potato/Valid/"

# %%
from tensorflow.keras.layers import Input

data_augmentation = tf.keras.Sequential([
    Input(shape=(224, 224, 3)),
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
  tf.keras.layers.Rescaling(1./255)
], name ="data_augmentation")

# %%
import tensorflow as tf

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = train_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE,
    shuffle = True
).cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

test_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = test_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE
).cache().prefetch(buffer_size=tf.data.AUTOTUNE)

valid_datasets = tf.keras.preprocessing.image_dataset_from_directory(
    directory = valid_dir,
    image_size = IMG_SIZE,
    label_mode = 'categorical',
    batch_size = BATCH_SIZE
)

class_names = valid_datasets.class_names
valid_data = valid_datasets.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
# Out:
# Found 900 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.
# Found 300 files belonging to 3 classes.

# %%
[(images, label_batch)] = train_data.take(1)
total_classes = label_batch.shape[-1]
total_classes
# Out:
# 3

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in train_data.take(1):
    for i in range(0,8):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")

# %%
checkpoint_path = "/CheckPoint/cp.weights.h5"
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path,
    save_weights_only=True,
    monitor='val_accuracy',
    save_best_only=True
)

# %%
model = tf.keras.Sequential([
    data_augmentation,
    tf.keras.layers.Conv2D(60, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(60, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.Conv2D(60, 3, activation='relu'),
    tf.keras.layers.MaxPool2D(pool_size=2),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(total_classes, activation='softmax', name='output_layers')

])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)       │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, None, None, 60)      │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, None, None, 60)      │          32,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, None, None, 60)      │          32,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 60)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output_layers (Dense)                │ (None, 3)                   │             183 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 66,783 (260.87 KB)
#  Trainable params: 66,783 (260.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss = 'categorical_crossentropy',
    optimizer = tf.keras.optimizers.Adam(),
    metrics = ['accuracy']
)

# %%
history = model.fit(
    train_data,
    epochs=200,
    validation_data = test_data,
    validation_steps = len(test_data),
    callbacks = [
        checkpoint_callback,
    ]
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.3190 - loss: 1.1017 - val_accuracy: 0.5900 - val_loss: 1.0569
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.5151 - loss: 1.0402 - val_accuracy: 0.3833 - val_loss: 0.9539
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.5778 - loss: 0.8744 - val_accuracy: 0.5100 - val_loss: 0.8077
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.6522 - loss: 0.7410 - val_accuracy: 0.6833 - val_loss: 0.6488
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7533 - loss: 0.6448 - val_accuracy: 0.7233 - val_loss: 0.5748
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.7329 - loss: 0.5744 - val_accuracy: 0.8167 - val_loss: 0.4745
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.8502 - loss: 0.4391 - val_accuracy: 0.8900 - val_loss: 0.3508
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.8761 - loss: 0.3824 - val_accuracy: 0.9333 - val_loss: 0.2711
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9095 - loss: 0.2904 - val_accuracy: 0.9067 - val_loss: 0.2666
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.8873 - loss: 0.2534 - val_accuracy: 0.7600 - val_loss: 0.4914
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.8126 - loss: 0.4227 - val_accuracy: 0.8367 - val_loss: 0.3229
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9076 - loss: 0.2799 - val_accuracy: 0.9433 - val_loss: 0.1752
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9306 - loss: 0.1916 - val_accuracy: 0.9633 - val_loss: 0.1372
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9309 - loss: 0.1873 - val_accuracy: 0.9033 - val_loss: 0.2285
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9271 - loss: 0.2074 - val_accuracy: 0.9433 - val_loss: 0.1469
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9331 - loss: 0.1848 - val_accuracy: 0.9467 - val_loss: 0.1514
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9341 - loss: 0.1670 - val_accuracy: 0.9400 - val_loss: 0.1612
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9105 - loss: 0.2214 - val_accuracy: 0.9467 - val_loss: 0.1525
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9406 - loss: 0.1899 - val_accuracy: 0.9267 - val_loss: 0.1540
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9476 - loss: 0.1588 - val_accuracy: 0.9467 - val_loss: 0.1382
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9564 - loss: 0.1178 - val_accuracy: 0.9367 - val_loss: 0.1585
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9394 - loss: 0.1561 - val_accuracy: 0.8333 - val_loss: 0.3787
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9530 - loss: 0.1354 - val_accuracy: 0.9000 - val_loss: 0.2097
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9540 - loss: 0.1343 - val_accuracy: 0.9333 - val_loss: 0.1494
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9487 - loss: 0.1295 - val_accuracy: 0.9100 - val_loss: 0.2118
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9547 - loss: 0.1315 - val_accuracy: 0.9500 - val_loss: 0.1290
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9739 - loss: 0.0986 - val_accuracy: 0.9467 - val_loss: 0.1179
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9411 - loss: 0.1445 - val_accuracy: 0.8767 - val_loss: 0.2354
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9324 - loss: 0.1763 - val_accuracy: 0.9600 - val_loss: 0.1212
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9532 - loss: 0.1270 - val_accuracy: 0.9267 - val_loss: 0.1553
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9587 - loss: 0.1169 - val_accuracy: 0.9733 - val_loss: 0.0872
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9497 - loss: 0.1354 - val_accuracy: 0.9700 - val_loss: 0.1113
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9428 - loss: 0.1458 - val_accuracy: 0.8033 - val_loss: 0.5944
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9234 - loss: 0.2110 - val_accuracy: 0.9633 - val_loss: 0.1035
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9269 - loss: 0.1801 - val_accuracy: 0.9767 - val_loss: 0.0843
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9367 - loss: 0.1423 - val_accuracy: 0.9467 - val_loss: 0.1196
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9386 - loss: 0.1568 - val_accuracy: 0.9533 - val_loss: 0.1040
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9668 - loss: 0.0950 - val_accuracy: 0.9100 - val_loss: 0.1849
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9623 - loss: 0.1101 - val_accuracy: 0.9433 - val_loss: 0.1141
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9654 - loss: 0.0966 - val_accuracy: 0.9800 - val_loss: 0.0608
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9317 - loss: 0.1836 - val_accuracy: 0.9767 - val_loss: 0.0827
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9679 - loss: 0.0883 - val_accuracy: 0.9267 - val_loss: 0.1852
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9582 - loss: 0.1252 - val_accuracy: 0.9433 - val_loss: 0.1254
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9708 - loss: 0.0894 - val_accuracy: 0.9033 - val_loss: 0.2539
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9673 - loss: 0.0966 - val_accuracy: 0.9200 - val_loss: 0.1479
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9530 - loss: 0.1103 - val_accuracy: 0.9300 - val_loss: 0.1355
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9698 - loss: 0.0905 - val_accuracy: 0.9033 - val_loss: 0.1971
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9652 - loss: 0.1023 - val_accuracy: 0.9133 - val_loss: 0.1878
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 85s 3s/step - accuracy: 0.9603 - loss: 0.1164 - val_accuracy: 0.9100 - val_loss: 0.1729
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.9766 - loss: 0.0798 - val_accuracy: 0.9767 - val_loss: 0.0694
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 96s 3s/step - accuracy: 0.9621 - loss: 0.0950 - val_accuracy: 0.9867 - val_loss: 0.0531
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 97s 3s/step - accuracy: 0.9831 - loss: 0.0589 - val_accuracy: 0.9667 - val_loss: 0.0918
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 106s 4s/step - accuracy: 0.9690 - loss: 0.0909 - val_accuracy: 0.9433 - val_loss: 0.1320
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9671 - loss: 0.0800 - val_accuracy: 0.9900 - val_loss: 0.0444
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - accuracy: 0.9471 - loss: 0.1161 - val_accuracy: 0.9733 - val_loss: 0.0756
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.9611 - loss: 0.1072 - val_accuracy: 0.9467 - val_loss: 0.1144
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.9775 - loss: 0.0717 - val_accuracy: 0.9933 - val_loss: 0.0535
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.9545 - loss: 0.1337 - val_accuracy: 0.9533 - val_loss: 0.0982
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9724 - loss: 0.0766 - val_accuracy: 0.9567 - val_loss: 0.1188
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9700 - loss: 0.0804 - val_accuracy: 0.9600 - val_loss: 0.1002
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9563 - loss: 0.0947 - val_accuracy: 0.9667 - val_loss: 0.0911
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9697 - loss: 0.0878 - val_accuracy: 0.9733 - val_loss: 0.0714
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9728 - loss: 0.1068 - val_accuracy: 0.9467 - val_loss: 0.1112
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9724 - loss: 0.0688 - val_accuracy: 0.9933 - val_loss: 0.0385
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9478 - loss: 0.1170 - val_accuracy: 0.9700 - val_loss: 0.0653
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9745 - loss: 0.0686 - val_accuracy: 0.9700 - val_loss: 0.0916
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.9763 - loss: 0.0706 - val_accuracy: 0.9100 - val_loss: 0.2030
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9723 - loss: 0.0848 - val_accuracy: 0.9200 - val_loss: 0.2098
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9847 - loss: 0.0650 - val_accuracy: 0.9833 - val_loss: 0.0456
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9665 - loss: 0.0918 - val_accuracy: 0.9767 - val_loss: 0.0605
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9744 - loss: 0.0753 - val_accuracy: 0.9367 - val_loss: 0.1391
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9648 - loss: 0.0951 - val_accuracy: 0.9800 - val_loss: 0.0521
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9655 - loss: 0.1028 - val_accuracy: 0.9667 - val_loss: 0.0918
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9690 - loss: 0.1191 - val_accuracy: 0.9167 - val_loss: 0.1685
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9690 - loss: 0.0679 - val_accuracy: 0.9500 - val_loss: 0.1100
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9654 - loss: 0.0806 - val_accuracy: 0.9600 - val_loss: 0.0905
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9775 - loss: 0.0576 - val_accuracy: 0.9433 - val_loss: 0.1331
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.9732 - loss: 0.0658 - val_accuracy: 0.9800 - val_loss: 0.0658
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9366 - loss: 0.1520 - val_accuracy: 0.9600 - val_loss: 0.1118
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - accuracy: 0.9489 - loss: 0.1693 - val_accuracy: 0.9300 - val_loss: 0.1538
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.9646 - loss: 0.1113 - val_accuracy: 0.9033 - val_loss: 0.2348
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 96s 3s/step - accuracy: 0.9568 - loss: 0.1174 - val_accuracy: 0.9467 - val_loss: 0.1354
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - accuracy: 0.9561 - loss: 0.1252 - val_accuracy: 0.9600 - val_loss: 0.0997
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.9711 - loss: 0.0960 - val_accuracy: 0.9000 - val_loss: 0.2839
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9282 - loss: 0.1656 - val_accuracy: 0.9833 - val_loss: 0.0523
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9836 - loss: 0.0603 - val_accuracy: 0.9933 - val_loss: 0.0422
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 64s 2s/step - accuracy: 0.9705 - loss: 0.0803 - val_accuracy: 0.9367 - val_loss: 0.1418
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9782 - loss: 0.0834 - val_accuracy: 0.9867 - val_loss: 0.0524
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.9790 - loss: 0.0763 - val_accuracy: 0.9800 - val_loss: 0.0465
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9802 - loss: 0.0523 - val_accuracy: 0.9667 - val_loss: 0.0870
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9741 - loss: 0.0740 - val_accuracy: 0.9200 - val_loss: 0.1485
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9829 - loss: 0.0514 - val_accuracy: 0.9500 - val_loss: 0.1095
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.9774 - loss: 0.0564 - val_accuracy: 0.9800 - val_loss: 0.0652
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9635 - loss: 0.0988 - val_accuracy: 0.9733 - val_loss: 0.0510
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9596 - loss: 0.1155 - val_accuracy: 0.9400 - val_loss: 0.1374
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9620 - loss: 0.0903 - val_accuracy: 0.9800 - val_loss: 0.0576
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 100s 3s/step - accuracy: 0.9607 - loss: 0.0882 - val_accuracy: 0.9767 - val_loss: 0.0746
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.9378 - loss: 0.1645 - val_accuracy: 0.9300 - val_loss: 0.1479
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9722 - loss: 0.0824 - val_accuracy: 0.9133 - val_loss: 0.2349
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9711 - loss: 0.0914 - val_accuracy: 0.9300 - val_loss: 0.2021
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9818 - loss: 0.0563 - val_accuracy: 0.9767 - val_loss: 0.0575
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.9779 - loss: 0.0537 - val_accuracy: 0.8867 - val_loss: 0.3004
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9641 - loss: 0.0915 - val_accuracy: 0.9700 - val_loss: 0.0770
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9744 - loss: 0.0623 - val_accuracy: 0.9633 - val_loss: 0.0873
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.9779 - loss: 0.0560 - val_accuracy: 0.9433 - val_loss: 0.1378
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9619 - loss: 0.1023 - val_accuracy: 0.9833 - val_loss: 0.0479
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.9766 - loss: 0.0760 - val_accuracy: 0.9633 - val_loss: 0.1090
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9837 - loss: 0.0540 - val_accuracy: 0.9667 - val_loss: 0.0691
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9664 - loss: 0.0688 - val_accuracy: 0.9467 - val_loss: 0.1347
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - accuracy: 0.9675 - loss: 0.0992 - val_accuracy: 0.9500 - val_loss: 0.1497
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.9353 - loss: 0.1718 - val_accuracy: 0.9333 - val_loss: 0.1510
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 3s/step - accuracy: 0.9747 - loss: 0.0760 - val_accuracy: 0.9600 - val_loss: 0.0988
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 66s 2s/step - accuracy: 0.9786 - loss: 0.0686 - val_accuracy: 0.9867 - val_loss: 0.0390
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9835 - loss: 0.0521 - val_accuracy: 0.9267 - val_loss: 0.1953
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.9697 - loss: 0.0898 - val_accuracy: 0.9633 - val_loss: 0.0932
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9822 - loss: 0.0453 - val_accuracy: 0.9333 - val_loss: 0.1489
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9839 - loss: 0.0478 - val_accuracy: 0.9500 - val_loss: 0.1062
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9779 - loss: 0.0610 - val_accuracy: 0.9500 - val_loss: 0.1091
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 69s 2s/step - accuracy: 0.9741 - loss: 0.0619 - val_accuracy: 0.9733 - val_loss: 0.0624
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - accuracy: 0.9639 - loss: 0.0827 - val_accuracy: 0.9800 - val_loss: 0.0681
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.9763 - loss: 0.0650 - val_accuracy: 0.9500 - val_loss: 0.1097
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9665 - loss: 0.1012 - val_accuracy: 0.9300 - val_loss: 0.1676
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9773 - loss: 0.0539 - val_accuracy: 0.9867 - val_loss: 0.0325
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9779 - loss: 0.0622 - val_accuracy: 0.9933 - val_loss: 0.0315
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9766 - loss: 0.0623 - val_accuracy: 0.9800 - val_loss: 0.0531
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9845 - loss: 0.0400 - val_accuracy: 0.9800 - val_loss: 0.0501
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9737 - loss: 0.0563 - val_accuracy: 0.9833 - val_loss: 0.0649
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9738 - loss: 0.0583 - val_accuracy: 0.9567 - val_loss: 0.1117
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9711 - loss: 0.0829 - val_accuracy: 0.9900 - val_loss: 0.0331
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9823 - loss: 0.0427 - val_accuracy: 0.9467 - val_loss: 0.1055
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9873 - loss: 0.0527 - val_accuracy: 0.9700 - val_loss: 0.0501
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9822 - loss: 0.0513 - val_accuracy: 0.9733 - val_loss: 0.0615
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9893 - loss: 0.0217 - val_accuracy: 0.9367 - val_loss: 0.1804
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9770 - loss: 0.0630 - val_accuracy: 0.8967 - val_loss: 0.2669
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9810 - loss: 0.0517 - val_accuracy: 0.9467 - val_loss: 0.1388
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9833 - loss: 0.0596 - val_accuracy: 0.9800 - val_loss: 0.0455
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.9808 - loss: 0.0561 - val_accuracy: 0.9833 - val_loss: 0.0678
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9931 - loss: 0.0392 - val_accuracy: 0.9600 - val_loss: 0.1073
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9551 - loss: 0.1449 - val_accuracy: 0.9600 - val_loss: 0.1088
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9801 - loss: 0.0557 - val_accuracy: 0.9733 - val_loss: 0.0583
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9812 - loss: 0.0533 - val_accuracy: 0.9233 - val_loss: 0.2121
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step - accuracy: 0.9669 - loss: 0.1013 - val_accuracy: 0.9767 - val_loss: 0.0481
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9891 - loss: 0.0364 - val_accuracy: 0.9167 - val_loss: 0.1929
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9692 - loss: 0.0710 - val_accuracy: 0.9733 - val_loss: 0.0625
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.9796 - loss: 0.0439 - val_accuracy: 0.9567 - val_loss: 0.0907
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9799 - loss: 0.0418 - val_accuracy: 0.9833 - val_loss: 0.0697
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9844 - loss: 0.0368 - val_accuracy: 0.9800 - val_loss: 0.0438
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9714 - loss: 0.0586 - val_accuracy: 0.9733 - val_loss: 0.0565
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9797 - loss: 0.0413 - val_accuracy: 0.9367 - val_loss: 0.1485
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9817 - loss: 0.0552 - val_accuracy: 0.9800 - val_loss: 0.0598
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9815 - loss: 0.0488 - val_accuracy: 0.9733 - val_loss: 0.0709
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9683 - loss: 0.0795 - val_accuracy: 0.9367 - val_loss: 0.1825
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 57s 2s/step - accuracy: 0.9806 - loss: 0.0502 - val_accuracy: 0.9800 - val_loss: 0.0567
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.9712 - loss: 0.0736 - val_accuracy: 0.9800 - val_loss: 0.0526
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9869 - loss: 0.0386 - val_accuracy: 0.9867 - val_loss: 0.0346
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9730 - loss: 0.0811 - val_accuracy: 0.9767 - val_loss: 0.0548
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9910 - loss: 0.0411 - val_accuracy: 0.9700 - val_loss: 0.1048
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9713 - loss: 0.0687 - val_accuracy: 0.9533 - val_loss: 0.1339
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.9901 - loss: 0.0283 - val_accuracy: 0.9767 - val_loss: 0.0396
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9859 - loss: 0.0373 - val_accuracy: 0.9867 - val_loss: 0.0501
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9850 - loss: 0.0344 - val_accuracy: 0.9900 - val_loss: 0.0400
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.9792 - loss: 0.0428 - val_accuracy: 0.8333 - val_loss: 0.7703
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.9383 - loss: 0.1363 - val_accuracy: 0.9800 - val_loss: 0.0507
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 81s 3s/step - accuracy: 0.9857 - loss: 0.0474 - val_accuracy: 0.9133 - val_loss: 0.2273
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.9656 - loss: 0.1137 - val_accuracy: 0.9800 - val_loss: 0.0509
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 70s 2s/step - accuracy: 0.9808 - loss: 0.0563 - val_accuracy: 0.9000 - val_loss: 0.3191
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 63s 2s/step - accuracy: 0.9711 - loss: 0.0666 - val_accuracy: 0.9867 - val_loss: 0.0379
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 72s 2s/step - accuracy: 0.9767 - loss: 0.0714 - val_accuracy: 0.8600 - val_loss: 0.4773
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - accuracy: 0.9302 - loss: 0.1962 - val_accuracy: 0.8700 - val_loss: 0.3652
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - accuracy: 0.9723 - loss: 0.0856 - val_accuracy: 0.9300 - val_loss: 0.1939
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9859 - loss: 0.0490 - val_accuracy: 0.9367 - val_loss: 0.1151
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9784 - loss: 0.0634 - val_accuracy: 0.9733 - val_loss: 0.0731
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9709 - loss: 0.0655 - val_accuracy: 0.9933 - val_loss: 0.0295
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9918 - loss: 0.0274 - val_accuracy: 0.9733 - val_loss: 0.0791
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9831 - loss: 0.0387 - val_accuracy: 0.9333 - val_loss: 0.1566
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9831 - loss: 0.0502 - val_accuracy: 0.9633 - val_loss: 0.1050
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9814 - loss: 0.0465 - val_accuracy: 0.9800 - val_loss: 0.0714
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9905 - loss: 0.0286 - val_accuracy: 0.9667 - val_loss: 0.0893
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9836 - loss: 0.0430 - val_accuracy: 0.9767 - val_loss: 0.0625
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9788 - loss: 0.0460 - val_accuracy: 0.9700 - val_loss: 0.0785
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9865 - loss: 0.0420 - val_accuracy: 0.9600 - val_loss: 0.1278
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9785 - loss: 0.0622 - val_accuracy: 0.9333 - val_loss: 0.1852
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9778 - loss: 0.0698 - val_accuracy: 0.9833 - val_loss: 0.0648
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.9763 - loss: 0.0602 - val_accuracy: 0.9833 - val_loss: 0.0595
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9950 - loss: 0.0200 - val_accuracy: 0.9900 - val_loss: 0.0389
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.9796 - loss: 0.0457 - val_accuracy: 0.9900 - val_loss: 0.0460
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.9773 - loss: 0.0533 - val_accuracy: 0.9633 - val_loss: 0.0937
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.9695 - loss: 0.1026 - val_accuracy: 0.9833 - val_loss: 0.0486
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9787 - loss: 0.0556 - val_accuracy: 0.9900 - val_loss: 0.0359
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9906 - loss: 0.0332 - val_accuracy: 0.9800 - val_loss: 0.0553
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 52s 2s/step - accuracy: 0.9788 - loss: 0.0491 - val_accuracy: 0.9733 - val_loss: 0.0545
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9813 - loss: 0.0451 - val_accuracy: 0.9700 - val_loss: 0.0769
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9703 - loss: 0.0725 - val_accuracy: 0.9800 - val_loss: 0.0626
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9845 - loss: 0.0329 - val_accuracy: 0.9833 - val_loss: 0.0351
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.9820 - loss: 0.0570 - val_accuracy: 0.9867 - val_loss: 0.0421
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.9843 - loss: 0.0474 - val_accuracy: 0.8267 - val_loss: 0.4444
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - accuracy: 0.9500 - loss: 0.1111 - val_accuracy: 0.9733 - val_loss: 0.0798
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9867 - loss: 0.0598 - val_accuracy: 0.9767 - val_loss: 0.0581
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9866 - loss: 0.0379 - val_accuracy: 0.9733 - val_loss: 0.0575
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.9853 - loss: 0.0413 - val_accuracy: 0.9933 - val_loss: 0.0299

# %%
def bestWeightModelEvaluate(model, weight_path, data):
  cp_model = tf.keras.models.clone_model(model)
  cp_model.compile(
      loss = tf.keras.losses.CategoricalCrossentropy(),
      optimizer = tf.keras.optimizers.Adam(),
      metrics = ['accuracy']
  )
  cp_model.load_weights(weight_path)
  cp_model.evaluate(data)

# %%
bestWeightModelEvaluate(
    model = model,
    weight_path= checkpoint_path,
    data = valid_data
)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 8s 543ms/step - accuracy: 0.9795 - loss: 0.0628

# %%
bestWeightModelEvaluate(
    model = model,
    weight_path= checkpoint_path,
    data = test_data
)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 456ms/step - accuracy: 0.9912 - loss: 0.0594

# %%
import requests

url = "https://github.com/HSAkash/Potato-Leaf-Disease-Dataset/raw/main/potato_pretrain_model.h5"
filename = "potato_pretrain_model.h5"

response = requests.get(url)

with open(filename, 'wb') as f:
    f.write(response.content)

print("Download complete: potato_pretrain_model.h5")
# Out:
# Download complete: potato_pretrain_model.h5

# %%
custom_objects = {
    'RandomFlip': tf.keras.layers.RandomFlip,
    'RandomRotation': tf.keras.layers.RandomRotation,
    'RandomZoom': tf.keras.layers.RandomZoom,
    'RandomHeight': tf.keras.layers.RandomHeight,
    'RandomWidth': tf.keras.layers.RandomWidth,
    'Rescaling': tf.keras.layers.Rescaling,
    # Add other custom layers if any
}
load_model = tf.keras.models.load_model("potato_pretrain_model.h5",custom_objects=custom_objects,compile=False)

# %%
load_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)       │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, None, None, 60)      │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, None, None, 60)      │          32,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, None, None, 60)      │          32,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 60)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output_layers (Dense)                │ (None, 3)                   │             183 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 66,783 (260.87 KB)
#  Trainable params: 66,783 (260.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ data_augmentation (Sequential)       │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, None, None, 60)      │           1,680 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, None, None, 60)      │          32,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, None, None, 60)      │          32,460 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, None, None, 60)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d_1           │ (None, 60)                  │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ output_layers (Dense)                │ (None, 3)                   │             183 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 66,783 (260.87 KB)
#  Trainable params: 66,783 (260.87 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy

load_model.compile(
    optimizer=Adam(),
    loss=CategoricalCrossentropy(),
    metrics=[CategoricalAccuracy()]
)

load_model.evaluate(test_data)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 370ms/step - categorical_accuracy: 0.9956 - loss: 0.0481
# [0.04237304627895355, 0.996666669845581]

# %%
load_model.evaluate(valid_data)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 259ms/step - categorical_accuracy: 0.9807 - loss: 0.0677
# [0.07074113190174103, 0.9800000190734863]

# %%
import numpy as np
predictions = load_model.predict(test_data)
predictions = np.argmax(predictions, axis=-1)
predictions.shape
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 258ms/step
# (300,)

# %%
plt.figure(figsize=(12,12))
for image_batch,label_batch in test_data.take(1):
    for i in range(0,8):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        true_class = class_names[np.argmax(label_batch[i])]
        predict_class = class_names[predictions[i]]
        title = f"""True:{true_class}\n Predict:{predict_class}"""
        plt.title(title, color='g' if true_class==predict_class else 'r')
        plt.axis("off")

# %%
import os
import pandas as pd
import seaborn as sns

def plot_class_distribution(directory, title):
    class_counts = {}
    for class_name in os.listdir(directory):
        class_path = os.path.join(directory, class_name)
        if os.path.isdir(class_path):
            class_counts[class_name] = len(os.listdir(class_path))

    df = pd.DataFrame(list(class_counts.items()), columns=["Class", "Count"])
    plt.figure(figsize=(8, 5))
    sns.barplot(x="Class", y="Count", data=df)
    plt.title(f"Class Distribution - {title}")
    plt.xlabel("Class")
    plt.ylabel("Number of Images")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

plot_class_distribution(train_dir, "Training Set")
plot_class_distribution(valid_dir, "Validation Set")
plot_class_distribution(test_dir, "Test Set")

# %%
def plot_accuracy_and_loss(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs_range = range(len(acc))

    plt.figure(figsize=(14, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Train Accuracy')
    plt.plot(epochs_range, val_acc, label='Val Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Train Loss')
    plt.plot(epochs_range, val_loss, label='Val Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.show()

plot_accuracy_and_loss(history)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Get all true labels
true_labels = []
for _, labels in test_data:
    true_labels.extend(np.argmax(labels.numpy(), axis=-1))

# Compute confusion matrix
cm = confusion_matrix(true_labels, predictions)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)

plt.figure(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, xticks_rotation=45)
plt.title("Confusion Matrix")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Prepare true binary labels
y_true_bin = []
for _, labels in test_data:
    y_true_bin.extend(labels.numpy())
y_true_bin = np.array(y_true_bin)

# Assuming `predictions_proba` is still available
predictions_proba = load_model.predict(test_data)

fpr = dict()
tpr = dict()
roc_auc = dict()
n_classes = len(class_names)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], predictions_proba[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10, 8))
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label=f"{class_names[i]} (AUC = {roc_auc[i]:.2f})")

plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - One-vs-Rest")
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 297ms/step
